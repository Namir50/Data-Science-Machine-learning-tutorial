# %% [markdown]
# <h3>SMOTE</h3>
# Synthetic Minority Oversampling Technique

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification

# %%
X,Y = make_classification(n_samples = 1000,
                    n_features=2, n_clusters_per_class=1,
                    weights=[0.90], random_state = 12, n_redundant=0)     #Weights 0.90 says 1 class should be 90% more than the other class

# %%
df1 = pd.DataFrame(X,columns = ['f1','f2'])
df2 = pd.DataFrame(Y, columns = ['target'])

# %%
df = pd.concat([df1,df2],axis = 1)

# %%
df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
df['target'].value_counts()
# Out:
# target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
plt.scatter(df['f1'],df['f2'],c = df['target'])

# %%
from imblearn.over_sampling import SMOTE

# %%
oversample = SMOTE()
X,Y = oversample.fit_resample(df[['f1','f2']],df['target'])

# %%
X.shape
# Out:
# (1800, 2)

# %%
Y.shape
# Out:
# (1800,)

# %%
oversampled_df = pd.concat([X,Y], axis=1)

# %%
oversampled_df.head()
# Out:
#          f1        f2  target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
oversampled_df['target'].value_counts()
# Out:
# target
# 0    900
# 1    900
# Name: count, dtype: int64

# %%
plt.scatter(oversampled_df['f1'],oversampled_df['f2'],c = oversampled_df['target'])
