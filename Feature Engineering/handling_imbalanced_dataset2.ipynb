# %%
import pandas as pd
from imblearn.over_sampling import SMOTE

# %%
df = pd.read_csv('synthetic_dataset.csv')

# %%
df.head()
# Out:
#    Feature1  Feature2  Class
# 0  5.496714  5.357787    0.0
# 1  4.861736  5.560785    0.0
# 2  5.647689  6.083051    0.0
# 3  6.523030  6.053802    0.0
# 4  4.765847  3.622331    0.0

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    200
# 1.0     30
# Name: count, dtype: int64

# %%
plt.scatter(df['Feature1'],df['Feature2'], c= df['Class'])

# %%
oversample = SMOTE()

# %%
X,Y = oversample.fit_resample(df[['Feature1', 'Feature2']], df['Class'])

# %%
X.shape
# Out:
# (400, 2)

# %%
Y.shape
# Out:
# (400,)

# %%
df_resampled  = pd.DataFrame(X, columns=['Feature1','Feature2'])
df_resampled['Class'] = Y

# %%
df_resampled['Class'].value_counts()
# Out:
# Class
# 0.0    200
# 1.0    200
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    Feature1  Feature2  Class
# 0  5.496714  5.357787    0.0
# 1  4.861736  5.560785    0.0
# 2  5.647689  6.083051    0.0
# 3  6.523030  6.053802    0.0
# 4  4.765847  3.622331    0.0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df_resampled['Feature1'],df_resampled['Feature2'], c= df_resampled['Class'])

# %%
from sklearn.utils import resample

# %%
df.head()
# Out:
#    Feature1  Feature2  Class
# 0  5.496714  5.357787    0.0
# 1  4.861736  5.560785    0.0
# 2  5.647689  6.083051    0.0
# 3  6.523030  6.053802    0.0
# 4  4.765847  3.622331    0.0

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    200
# 1.0     30
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# Feature1    float64
# Feature2    float64
# Class       float64
# dtype: object

# %%
df['Class'] = df['Class'].astype(int)
df_majority = df[df['Class'] == 0.0]
df_minority = df[df['Class'] == 1.0]

# %%
df_downsampled = resample(df_majority, 
                            replace=True, 
                            n_samples=len(df_minority),
                            random_state=42)
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 df_downsampled = resample(df_majority,
#       2                             replace=True,
#       3                             n_samples=len(df_minority),
#       4                             random_state=42)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\utils\_param_validation.py:206, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     203 to_ignore += ["self", "cls"]
#     204 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 206 validate_parameter_constraints(
#     207     parameter_constraints, params, caller_name=func.__qualname__
#     208 )
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
# ...

# %%
df_upsampled.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 df_upsampled.shape
#
# NameError: name 'df_upsampled' is not defined
